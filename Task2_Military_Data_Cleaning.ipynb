# %%
import pandas as pd

df = pd.read_csv("military_raw_data (1).csv")

print(df.shape)
print(df.info())
print(df.isnull().sum())
# Out:
# (145, 55)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 55 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  145 non-null    object
#  1   total-population-by-country              145 non-null    int64
#  2   available-military-manpower              145 non-null    int64
#  3   manpower-fit-for-military-service        145 non-null    int64
#  4   manpower-reaching-military-age-annually  145 non-null    int64
#  5   active-military-manpower                 145 non-null    int64
#  6   active-reserve-military-manpower         145 non-null    int64
#  7   manpower-paramilitary                    145 non-null    int64
#  8   aircraft-total                           145 non-null    int64
#  9   aircraft-total-fighters                  145 non-null    int64
#  10  aircraft-total-attack-types              145 non-null    int64
#  11  aircraft-total-transports                145 non-null    int64
#  12  aircraft-total-trainers                  145 non-null    int64
#  13  aircraft-total-special-mission           145 non-null    int64
#  14  aircraft-total-tanker-fleet              145 non-null    int64
#  15  aircraft-helicopters-total               145 non-null    int64
#  16  aircraft-helicopters-attack              145 non-null    int64
#  17  armor-tanks-total                        145 non-null    int64
#  18  armor-apc-total                          145 non-null    int64
#  19  armor-self-propelled-guns-total          145 non-null    int64
#  20  armor-towed-artillery-total              145 non-null    int64
#  21  armor-mlrs-total                         145 non-null    int64
#  22  navy-ships                               145 non-null    int64
#  23  navy-force-by-tonnage                    47 non-null     float64
#  24  navy-aircraft-carriers                   145 non-null    int64
#  25  navy-helo-carriers                       145 non-null    int64
#  26  navy-submarines                          145 non-null    int64
#  27  navy-destroyers                          145 non-null    int64
#  28  navy-frigates                            145 non-null    int64
#  29  navy-corvettes                           145 non-null    int64
#  30  navy-patrol-coastal-craft                145 non-null    int64
#  31  navy-mine-warfare-craft                  145 non-null    int64
#  32  defense-spending-budget                  145 non-null    float64
#  33  external-debt-by-country                 145 non-null    float64
#  34  purchasing-power-parity                  145 non-null    float64
#  35  reserves-of-foreign-exchange-and-gold    145 non-null    float64
#  36  major-serviceable-airports-by-country    145 non-null    int64
#  37  labor-force-by-country                   145 non-null    int64
#  38  major-ports-and-terminals                145 non-null    int64
#  39  merchant-marine-strength-by-country      145 non-null    int64
#  40  railway-coverage                         145 non-null    int64
#  41  roadway-coverage                         145 non-null    int64
#  42  oil-production-by-country                145 non-null    int64
#  43  oil-consumption-by-country               145 non-null    int64
#  44  proven-oil-reserves-by-country           145 non-null    float64
#  45  natural-gas-production-by-country        145 non-null    float64
#  46  natural-gas-consumption-by-country       145 non-null    float64
#  47  proven-natural-gas-reserves-by-country   145 non-null    float64
#  48  coal-production-by-country               145 non-null    int64
#  49  coal-consumption-by-country              145 non-null    int64
#  50  proven-coal-reserves-by-country          145 non-null    float64
#  51  square-land-area                         145 non-null    int64
#  52  coastline-coverage                       145 non-null    int64
#  53  border-coverage                          145 non-null    int64
#  54  waterway-coverage                        145 non-null    int64
# dtypes: float64(10), int64(44), object(1)
# memory usage: 62.4+ KB
# None
# country                                     0
# total-population-by-country                 0
# available-military-manpower                 0
# manpower-fit-for-military-service           0
# manpower-reaching-military-age-annually     0
# active-military-manpower                    0
# active-reserve-military-manpower            0
# manpower-paramilitary                       0
# aircraft-total                              0
# aircraft-total-fighters                     0
# aircraft-total-attack-types                 0
# aircraft-total-transports                   0
# aircraft-total-trainers                     0
# aircraft-total-special-mission              0
# aircraft-total-tanker-fleet                 0
# aircraft-helicopters-total                  0
# aircraft-helicopters-attack                 0
# armor-tanks-total                           0
# armor-apc-total                             0
# armor-self-propelled-guns-total             0
# armor-towed-artillery-total                 0
# armor-mlrs-total                            0
# navy-ships                                  0
# navy-force-by-tonnage                      98
# navy-aircraft-carriers                      0
# navy-helo-carriers                          0
# navy-submarines                             0
# navy-destroyers                             0
# navy-frigates                               0
# navy-corvettes                              0
# navy-patrol-coastal-craft                   0
# navy-mine-warfare-craft                     0
# defense-spending-budget                     0
# external-debt-by-country                    0
# purchasing-power-parity                     0
# reserves-of-foreign-exchange-and-gold       0
# major-serviceable-airports-by-country       0
# labor-force-by-country                      0
# major-ports-and-terminals                   0
# merchant-marine-strength-by-country         0
# railway-coverage                            0
# roadway-coverage                            0
# oil-production-by-country                   0
# oil-consumption-by-country                  0
# proven-oil-reserves-by-country              0
# natural-gas-production-by-country           0
# natural-gas-consumption-by-country          0
# proven-natural-gas-reserves-by-country      0
# coal-production-by-country                  0
# coal-consumption-by-country                 0
# proven-coal-reserves-by-country             0
# square-land-area                            0
# coastline-coverage                          0
# border-coverage                             0
# waterway-coverage                           0
# dtype: int64

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# %%
df["country"] = df["country"].fillna("Unknown")

# %%
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
df[numeric_cols] = df[numeric_cols].fillna(0)

# %%
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
df = df.drop_duplicates(subset="country")

# %%
df = df.loc[df[numeric_cols].sum(axis=1) != 0]

# %%
print("Final shape:", df.shape)
print(df.isnull().sum())
# Out:
# Final shape: (145, 55)
# country                                    0
# total-population-by-country                0
# available-military-manpower                0
# manpower-fit-for-military-service          0
# manpower-reaching-military-age-annually    0
# active-military-manpower                   0
# active-reserve-military-manpower           0
# manpower-paramilitary                      0
# aircraft-total                             0
# aircraft-total-fighters                    0
# aircraft-total-attack-types                0
# aircraft-total-transports                  0
# aircraft-total-trainers                    0
# aircraft-total-special-mission             0
# aircraft-total-tanker-fleet                0
# aircraft-helicopters-total                 0
# aircraft-helicopters-attack                0
# armor-tanks-total                          0
# armor-apc-total                            0
# armor-self-propelled-guns-total            0
# armor-towed-artillery-total                0
# armor-mlrs-total                           0
# navy-ships                                 0
# navy-force-by-tonnage                      0
# navy-aircraft-carriers                     0
# navy-helo-carriers                         0
# navy-submarines                            0
# navy-destroyers                            0
# navy-frigates                              0
# navy-corvettes                             0
# navy-patrol-coastal-craft                  0
# navy-mine-warfare-craft                    0
# defense-spending-budget                    0
# external-debt-by-country                   0
# purchasing-power-parity                    0
# reserves-of-foreign-exchange-and-gold      0
# major-serviceable-airports-by-country      0
# labor-force-by-country                     0
# major-ports-and-terminals                  0
# merchant-marine-strength-by-country        0
# railway-coverage                           0
# roadway-coverage                           0
# oil-production-by-country                  0
# oil-consumption-by-country                 0
# proven-oil-reserves-by-country             0
# natural-gas-production-by-country          0
# natural-gas-consumption-by-country         0
# proven-natural-gas-reserves-by-country     0
# coal-production-by-country                 0
# coal-consumption-by-country                0
# proven-coal-reserves-by-country            0
# square-land-area                           0
# coastline-coverage                         0
# border-coverage                            0
# waterway-coverage                          0
# dtype: int64

# %%
df.to_csv("cleaned_country_military_data.csv", index=False)

# %%
from google.colab import files
files.download("cleaned_country_military_data.csv")
