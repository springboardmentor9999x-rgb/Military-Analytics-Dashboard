# %% [markdown]
# # 🌍 Global Military KPI Analysis
#
# This notebook analyzes global military strength using standardized datasets
# and computes strategic KPIs such as assets per capita, defense burden,
# personnel density, air power ratio, and coalition strength.
#
# **Tools Used:** Python, Pandas, NumPy, Jupyter Notebook
# **Year:** 2025

# %% [markdown]
# ## 1️⃣ Data Loading
#
# We load the cleaned and standardized global military dataset
# containing country-wise military, economic, and geographic indicators.

# %% [markdown]
# ## 2️⃣ Key Performance Indicator (KPI) Calculations
#
# The following KPIs are computed to enable fair cross-country comparison:
# - Assets per Capita
# - Defense Budget to GDP Ratio
# - Personnel Density
# - Defense Budget per Soldier
# - Air Power Ratio
# - Armor Intensity Index
# - Naval Strength per Coastline
# - Military Burden Index

# %% [markdown]
# ## 3️⃣ Final Output
#
# The final dataset contains all computed KPIs and can be used for:
# - Ranking military power
# - Alliance-level analysis
# - Dashboard visualization

# %% [markdown]
# Kernel → Restart & Run All

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("military_kpi_enhanced.csv")

# %%
df.columns
# Out:
# Index(['Country', 'capital_city', 'region', 'continent', 'alliance',
#        'NATO_Status', 'year', 'power_index_rank', 'power_index_score',
#        'active_personnel', 'reserve_personnel', 'total_personnel',
#        'total_aircraft', 'fighter_aircraft', 'attack_aircraft',
#        'transport_aircraft', 'helicopters', 'tanks', 'armored_vehicles',
#        'artillery_units', 'naval_assets', 'aircraft_carriers', 'submarines',
#        'defense_budget_usd', 'gdp_usd', 'population', 'land_area_sq_km',
#        'coastline_km', 'fit_for_service',
#        'population_reaching_military_age_annually', 'paramilitary',
#        'trainer_aircraft', 'special_mission_aircraft', 'tanker_aircraft',
#        'attack_helicopters', 'self_propelled_artillery', 'towed_artillery',
#        'rocket_projectors', 'helicopter_carriers', 'destroyers', 'frigates',
#        'corvettes', 'coastal_patrol_craft', 'mine_warfare_craft',
#        'external_debt_usd', 'foreign_exchange_and_gold_reserves_usd',
# ...

# %%
df.to_csv("final_military_kpi_output.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 99 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    145 non-null    object
#  1   capital_city                               145 non-null    object
#  2   region                                     145 non-null    object
#  3   continent                                  145 non-null    object
#  4   alliance                                   145 non-null    object
#  5   NATO_Status                                145 non-null    object
#  6   year                                       145 non-null    int64
#  7   power_index_rank                           145 non-null    int64
#  8   power_index_score                          145 non-null    float64
#  9   active_personnel                           145 non-null    int64
# ...

# %%
df.to_csv("final_military_kpi_output.csv", index=False)

# %%
df.to_csv("final_military_kpi_output.csv", index=False)
