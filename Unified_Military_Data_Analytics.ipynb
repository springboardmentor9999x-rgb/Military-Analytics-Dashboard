# %%
import requests                      # To send HTTP requests
from bs4 import BeautifulSoup        # For parsing HTML content
import pandas as pd                  # For data manipulation
import re                            # For cleaning numeric values

# %%
# ======================================================
# Project: Unified Military Analytics & Comparison Dashboard
# Author : Rutuja Ghodake
# Description:
# Collects global military data from GlobalFirepower.com
# and merges all metrics into a single structured dataset.
# ======================================================

import requests                      # To send HTTP requests
from bs4 import BeautifulSoup        # For parsing HTML content
import pandas as pd                  # For data manipulation
import re                            # For cleaning numeric values(regular expression)

# ------------------------------
# Global Headers
# ------------------------------
HEADERS = {
    "User-Agent": "Mozilla/5.0"
}

# -------------------------------------------------------
# Read URLs from text file
# -------------------------------------------------------
def read_links_txt(path):
    links = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line.startswith("http"):
                links.append(line)
    return links


# -------------------------------------------------------
# Main Scraping Function
# -------------------------------------------------------
def scrape_global_firepower():

    base_url = "https://www.globalfirepower.com/countries-listing.php"
    metric_urls = read_links_txt("All_links.txt")

    # -------------------------------
    # STEP 1: Fetch country list
    # -------------------------------
    response = requests.get(base_url, headers=HEADERS)
    soup = BeautifulSoup(response.text, "html.parser")

    containers = soup.select("div.picTrans.recordsetContainer")

    countries = []
    ranks = []

    for box in containers:
        try:
            country = box.find("span", class_="textWhite textLarge textShadow").text.strip()
            rank = box.find("span", class_="textWhite textLarge textBold").text.strip()
            countries.append(country)
            ranks.append(rank)
        except:
            continue

    df = pd.DataFrame({
        "Country": countries,
        "Rank": ranks
    })

    # -------------------------------
    # STEP 2: Extract all metrics
    # -------------------------------
    for url in metric_urls:
        print(f"Scraping: {url}")

        response = requests.get(url, headers=HEADERS)
        soup = BeautifulSoup(response.text, "html.parser")

        rows = soup.select("div.picTrans.recordsetContainer")

        temp_countries = []
        values = []

        for row in rows:
            try:
                country = row.find("span", class_="textWhite textLarge textShadow").text.strip()
                value = row.find_all("span", class_="textWhite textLarge")[-1].text.strip()
                temp_countries.append(country)
                values.append(value)
            except:
                continue

        column_name = url.split("/")[-1].replace(".php", "")

        temp_df = pd.DataFrame({
            "Country": temp_countries,
            column_name: values
        })

        df = df.merge(temp_df, on="Country", how="left")

    # -------------------------------
    # STEP 3: Clean numeric values
    # -------------------------------
    for col in df.columns[2:]:
        df[col] = (
            df[col]
            .astype(str)
            .str.replace(",", "", regex=False)
            .str.extract(r"(\d+\.?\d*)")[0]
        )

    return df


# -------------------------------------------------------
# RUN SCRIPT
# -------------------------------------------------------
df = scrape_global_firepower()

# Save output
df.to_csv("global_military_data_final.csv", index=False)

# Display results
print("\n✅ Data extraction completed successfully!")
print("Total Countries:", len(df))
print("Total Features:", len(df.columns))
print("\nPreview:\n")
print(df.head())
# Out:
# Scraping: https://www.globalfirepower.com/total-population-by-country.php
# Scraping: https://www.globalfirepower.com/available-military-manpower.php
# Scraping: https://www.globalfirepower.com/manpower-fit-for-military-service.php
# Scraping: https://www.globalfirepower.com/manpower-reaching-military-age-annually.php
# Scraping: https://www.globalfirepower.com/active-military-manpower.php
# Scraping: https://www.globalfirepower.com/active-reserve-military-manpower.php
# Scraping: https://www.globalfirepower.com/manpower-paramilitary.php
# Scraping: https://www.globalfirepower.com/capital-cities-by-total-population.php
# Scraping: https://www.globalfirepower.com/aircraft-total.php
# Scraping: https://www.globalfirepower.com/aircraft-total-fighters.php
# Scraping: https://www.globalfirepower.com/aircraft-total-attack-types.php
# Scraping: https://www.globalfirepower.com/aircraft-total-transports.php
# Scraping: https://www.globalfirepower.com/aircraft-total-trainers.php
# Scraping: https://www.globalfirepower.com/aircraft-total-special-mission.php
# Scraping: https://www.globalfirepower.com/aircraft-total-tanker-fleet.php
# Scraping: https://www.globalfirepower.com/aircraft-helicopters-total.php
# Scraping: https://www.globalfirepower.com/aircraft-helicopters-attack.php
# Scraping: https://www.globalfirepower.com/armor-tanks-total.php
# Scraping: https://www.globalfirepower.com/armor-apc-total.php
# Scraping: https://www.globalfirepower.com/armor-self-propelled-guns-total.php
# Scraping: https://www.globalfirepower.com/armor-towed-artillery-total.php
# Scraping: https://www.globalfirepower.com/armor-mlrs-total.php
# Scraping: https://www.globalfirepower.com/navy-ships.php
# Scraping: https://www.globalfirepower.com/navy-force-by-tonnage.php
# Scraping: https://www.globalfirepower.com/navy-aircraft-carriers.php
# Scraping: https://www.globalfirepower.com/navy-helo-carriers.php
# Scraping: https://www.globalfirepower.com/navy-submarines.php
# Scraping: https://www.globalfirepower.com/navy-destroyers.php
# Scraping: https://www.globalfirepower.com/navy-frigates.php
# Scraping: https://www.globalfirepower.com/navy-corvettes.php
# Scraping: https://www.globalfirepower.com/navy-patrol-coastal-craft.php
# Scraping: https://www.globalfirepower.com/navy-mine-warfare-craft.php
# Scraping: https://www.globalfirepower.com/defense-spending-budget.php
# Scraping: https://www.globalfirepower.com/external-debt-by-country.php
# Scraping: https://www.globalfirepower.com/purchasing-power-parity.php
# Scraping: https://www.globalfirepower.com/reserves-of-foreign-exchange-and-gold.php
# Scraping: https://www.globalfirepower.com/major-serviceable-airports-by-country.php
# Scraping: https://www.globalfirepower.com/labor-force-by-country.php
# Scraping: https://www.globalfirepower.com/major-ports-and-terminals.php
# Scraping: https://www.globalfirepower.com/railway-coverage.php
# Scraping: https://www.globalfirepower.com/roadway-coverage.php
# Scraping: https://www.globalfirepower.com/oil-production-by-country.php
# Scraping: https://www.globalfirepower.com/oil-consumption-by-country.php
# Scraping: https://www.globalfirepower.com/proven-oil-reserves-by-country.php
# Scraping: https://www.globalfirepower.com/natural-gas-production-by-country.php
# Scraping: https://www.globalfirepower.com/natural-gas-consumption-by-country.php
# Scraping: https://www.globalfirepower.com/proven-natural-gas-reserves-by-country.php
# Scraping: https://www.globalfirepower.com/coal-production-by-country.php
# Scraping: https://www.globalfirepower.com/coal-consumption-by-country.php
# Scraping: https://www.globalfirepower.com/proven-coal-reserves-by-country.php
# Scraping: https://www.globalfirepower.com/square-land-area.php
# Scraping: https://www.globalfirepower.com/coastline-coverage.php
# Scraping: https://www.globalfirepower.com/border-coverage.php
# Scraping: https://www.globalfirepower.com/waterway-coverage.php
#
# ✅ Data extraction completed successfully!
# Total Countries: 145
# Total Features: 56
#
# Preview:
#
#          Country Rank total-population-by-country available-military-manpower  \
# 0  United States    1                   341963408                   150463900
# 1         Russia    2                   140820810                    69002197
# 2          China    3                  1415043270                   764123366
# 3          India    4                  1409128296                   662290299
# 4    South Korea    5                    52081799                    26040900
#
#   manpower-fit-for-military-service manpower-reaching-military-age-annually  \
# 0                         124816644                                 4445524
# 1                          46189226                                 1267387
# 2                         626864169                                19810606
# 3                         522786598                                23955181
# 4                          21353538                                  416654
#
#   active-military-manpower active-reserve-military-manpower  \
# 0                  1328000                           799500
# 1                  1320000                          2000000
# 2                  2035000                           510000
# 3                  1455550                          1155000
# 4                   600000                          3100000
#
#   manpower-paramilitary capital-cities-by-total-population  ...  \
# 0                     0                                NaN  ...
# 1                250000                                NaN  ...
# 2                625000                                NaN  ...
# 3               2527000                                NaN  ...
# 4                120000                                NaN  ...
#
#   natural-gas-production-by-country natural-gas-consumption-by-country  \
# 0                     1029000000000                       914301000000
# 1                      617830000000                       472239000000
# 2                      225341000000                       366160000000
# 3                       33170000000                        58867000000
# 4                          55127000                        59480000000
#
#   proven-natural-gas-reserves-by-country coal-production-by-country  \
# 0                         13402000000000                  548849000
# 1                         47805000000000                  508190000
# 2                          6654000000000                 4827000000
# 3                          1381000000000                  985671000
# 4                             7079000000                   15595000
#
#   coal-consumption-by-country proven-coal-reserves-by-country  \
# 0                   476044000                    248941000000
# 1                   310958000                    162166000000
# 2                  5313000000                    143197000000
# 3                  1200000000                    111052000000
# 4                   136413000                       326000000
#
#   square-land-area coastline-coverage border-coverage waterway-coverage
# 0          9833517              19924           12002             41009
# 1         17098242              37653           22407            102000
# 2          9596960              14500           22457             27700
# 3          3287263               7000           13888             14500
# 4            99720               2413             237              1600
#
# [5 rows x 56 columns]

# %%
#Read csv data by using pandas library
import pandas as pd

df = pd.read_csv("global_military_data_final.csv")

# Preview data
df.head()
# Out:
#          Country  Rank  total-population-by-country  \
# 0  United States     1                    341963408
# 1         Russia     2                    140820810
# 2          China     3                   1415043270
# 3          India     4                   1409128296
# 4    South Korea     5                     52081799
#
#    available-military-manpower  manpower-fit-for-military-service  \
# 0                    150463900                          124816644
# 1                     69002197                           46189226
# 2                    764123366                          626864169
# 3                    662290299                          522786598
# 4                     26040900                           21353538
#
#    manpower-reaching-military-age-annually  active-military-manpower  \
# 0                                  4445524                   1328000
# 1                                  1267387                   1320000
# 2                                 19810606                   2035000
# 3                                 23955181                   1455550
# 4                                   416654                    600000
#
#    active-reserve-military-manpower  manpower-paramilitary  \
# 0                            799500                      0
# 1                           2000000                 250000
# 2                            510000                 625000
# 3                           1155000                2527000
# 4                           3100000                 120000
#
#    capital-cities-by-total-population  ...  natural-gas-production-by-country  \
# 0                                 NaN  ...                      1029000000000
# 1                                 NaN  ...                       617830000000
# 2                                 NaN  ...                       225341000000
# 3                                 NaN  ...                        33170000000
# 4                                 NaN  ...                           55127000
#
#    natural-gas-consumption-by-country  proven-natural-gas-reserves-by-country  \
# 0                        914301000000                          13402000000000
# 1                        472239000000                          47805000000000
# 2                        366160000000                           6654000000000
# 3                         58867000000                           1381000000000
# 4                         59480000000                              7079000000
#
#    coal-production-by-country  coal-consumption-by-country  \
# 0                   548849000                    476044000
# 1                   508190000                    310958000
# 2                  4827000000                   5313000000
# 3                   985671000                   1200000000
# 4                    15595000                    136413000
#
#    proven-coal-reserves-by-country  square-land-area  coastline-coverage  \
# 0                     248941000000           9833517               19924
# 1                     162166000000          17098242               37653
# 2                     143197000000           9596960               14500
# 3                     111052000000           3287263                7000
# 4                        326000000             99720                2413
#
#    border-coverage  waterway-coverage
# 0            12002              41009
# 1            22407             102000
# 2            22457              27700
# 3            13888              14500
# 4              237               1600
#
# [5 rows x 56 columns]

# %%
#Understand Data Types & Null Values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  145 non-null    object
#  1   Rank                                     145 non-null    int64
#  2   total-population-by-country              145 non-null    int64
#  3   available-military-manpower              145 non-null    int64
#  4   manpower-fit-for-military-service        145 non-null    int64
#  5   manpower-reaching-military-age-annually  145 non-null    int64
#  6   active-military-manpower                 145 non-null    int64
#  7   active-reserve-military-manpower         145 non-null    int64
#  8   manpower-paramilitary                    145 non-null    int64
#  9   capital-cities-by-total-population       3 non-null      float64
#  10  aircraft-total                           145 non-null    int64
#  11  aircraft-total-fighters                  145 non-null    int64
#  12  aircraft-total-attack-types              145 non-null    int64
#  13  aircraft-total-transports                145 non-null    int64
#  14  aircraft-total-trainers                  145 non-null    int64
#  15  aircraft-total-special-mission           145 non-null    int64
#  16  aircraft-total-tanker-fleet              145 non-null    int64
#  17  aircraft-helicopters-total               145 non-null    int64
#  18  aircraft-helicopters-attack              145 non-null    int64
#  19  armor-tanks-total                        145 non-null    int64
#  20  armor-apc-total                          145 non-null    int64
#  21  armor-self-propelled-guns-total          145 non-null    int64
#  22  armor-towed-artillery-total              145 non-null    int64
#  23  armor-mlrs-total                         145 non-null    int64
#  24  navy-ships                               145 non-null    int64
#  25  navy-force-by-tonnage                    47 non-null     float64
#  26  navy-aircraft-carriers                   145 non-null    int64
#  27  navy-helo-carriers                       145 non-null    int64
#  28  navy-submarines                          145 non-null    int64
#  29  navy-destroyers                          145 non-null    int64
#  30  navy-frigates                            145 non-null    int64
#  31  navy-corvettes                           145 non-null    int64
#  32  navy-patrol-coastal-craft                145 non-null    int64
#  33  navy-mine-warfare-craft                  145 non-null    int64
#  34  defense-spending-budget                  145 non-null    int64
#  35  external-debt-by-country                 145 non-null    int64
#  36  purchasing-power-parity                  145 non-null    int64
#  37  reserves-of-foreign-exchange-and-gold    145 non-null    int64
#  38  major-serviceable-airports-by-country    145 non-null    int64
#  39  labor-force-by-country                   145 non-null    int64
#  40  major-ports-and-terminals                145 non-null    int64
#  41  railway-coverage                         145 non-null    int64
#  42  roadway-coverage                         145 non-null    int64
#  43  oil-production-by-country                145 non-null    int64
#  44  oil-consumption-by-country               145 non-null    int64
#  45  proven-oil-reserves-by-country           145 non-null    int64
#  46  natural-gas-production-by-country        145 non-null    int64
#  47  natural-gas-consumption-by-country       145 non-null    int64
#  48  proven-natural-gas-reserves-by-country   145 non-null    int64
#  49  coal-production-by-country               145 non-null    int64
#  50  coal-consumption-by-country              145 non-null    int64
#  51  proven-coal-reserves-by-country          145 non-null    int64
#  52  square-land-area                         145 non-null    int64
#  53  coastline-coverage                       145 non-null    int64
#  54  border-coverage                          145 non-null    int64
#  55  waterway-coverage                        145 non-null    int64
# dtypes: float64(2), int64(53), object(1)
# memory usage: 63.6+ KB

# %%
# Clean Column Names
df.columns = (
    df.columns
    .str.replace("-", "_")
    .str.replace(" ", "_")
    .str.title()
)

# %%
# Remove Special Characters (commas, tabs, symbols)

import re  #regular expression

for col in df.columns[2:]:  # Skip Country & Rank
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .str.replace(r"\s+", "", regex=True)
    )
df.columns
# Out:
# Index(['Country', 'Rank', 'Total_Population_By_Country',
#        'Available_Military_Manpower', 'Manpower_Fit_For_Military_Service',
#        'Manpower_Reaching_Military_Age_Annually', 'Active_Military_Manpower',
#        'Active_Reserve_Military_Manpower', 'Manpower_Paramilitary',
#        'Capital_Cities_By_Total_Population', 'Aircraft_Total',
#        'Aircraft_Total_Fighters', 'Aircraft_Total_Attack_Types',
#        'Aircraft_Total_Transports', 'Aircraft_Total_Trainers',
#        'Aircraft_Total_Special_Mission', 'Aircraft_Total_Tanker_Fleet',
#        'Aircraft_Helicopters_Total', 'Aircraft_Helicopters_Attack',
#        'Armor_Tanks_Total', 'Armor_Apc_Total',
#        'Armor_Self_Propelled_Guns_Total', 'Armor_Towed_Artillery_Total',
#        'Armor_Mlrs_Total', 'Navy_Ships', 'Navy_Force_By_Tonnage',
#        'Navy_Aircraft_Carriers', 'Navy_Helo_Carriers', 'Navy_Submarines',
#        'Navy_Destroyers', 'Navy_Frigates', 'Navy_Corvettes',
#        'Navy_Patrol_Coastal_Craft', 'Navy_Mine_Warfare_Craft',
#        'Defense_Spending_Budget', 'External_Debt_By_Country',
#        'Purchasing_Power_Parity', 'Reserves_Of_Foreign_Exchange_And_Gold',
#        'Major_Serviceable_Airports_By_Country', 'Labor_Force_By_Country',
#        'Major_Ports_And_Terminals', 'Railway_Coverage', 'Roadway_Coverage',
#        'Oil_Production_By_Country', 'Oil_Consumption_By_Country',
#        'Proven_Oil_Reserves_By_Country', 'Natural_Gas_Production_By_Country',
#        'Natural_Gas_Consumption_By_Country',
#        'Proven_Natural_Gas_Reserves_By_Country', 'Coal_Production_By_Country',
#        'Coal_Consumption_By_Country', 'Proven_Coal_Reserves_By_Country',
#        'Square_Land_Area', 'Coastline_Coverage', 'Border_Coverage',
#        'Waterway_Coverage'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Country', 'Rank', 'Total_Population_By_Country',
#        'Available_Military_Manpower', 'Manpower_Fit_For_Military_Service',
#        'Manpower_Reaching_Military_Age_Annually', 'Active_Military_Manpower',
#        'Active_Reserve_Military_Manpower', 'Manpower_Paramilitary',
#        'Capital_Cities_By_Total_Population', 'Aircraft_Total',
#        'Aircraft_Total_Fighters', 'Aircraft_Total_Attack_Types',
#        'Aircraft_Total_Transports', 'Aircraft_Total_Trainers',
#        'Aircraft_Total_Special_Mission', 'Aircraft_Total_Tanker_Fleet',
#        'Aircraft_Helicopters_Total', 'Aircraft_Helicopters_Attack',
#        'Armor_Tanks_Total', 'Armor_Apc_Total',
#        'Armor_Self_Propelled_Guns_Total', 'Armor_Towed_Artillery_Total',
#        'Armor_Mlrs_Total', 'Navy_Ships', 'Navy_Force_By_Tonnage',
#        'Navy_Aircraft_Carriers', 'Navy_Helo_Carriers', 'Navy_Submarines',
#        'Navy_Destroyers', 'Navy_Frigates', 'Navy_Corvettes',
#        'Navy_Patrol_Coastal_Craft', 'Navy_Mine_Warfare_Craft',
#        'Defense_Spending_Budget', 'External_Debt_By_Country',
#        'Purchasing_Power_Parity', 'Reserves_Of_Foreign_Exchange_And_Gold',
#        'Major_Serviceable_Airports_By_Country', 'Labor_Force_By_Country',
#        'Major_Ports_And_Terminals', 'Railway_Coverage', 'Roadway_Coverage',
#        'Oil_Production_By_Country', 'Oil_Consumption_By_Country',
#        'Proven_Oil_Reserves_By_Country', 'Natural_Gas_Production_By_Country',
#        'Natural_Gas_Consumption_By_Country',
#        'Proven_Natural_Gas_Reserves_By_Country', 'Coal_Production_By_Country',
#        'Coal_Consumption_By_Country', 'Proven_Coal_Reserves_By_Country',
#        'Square_Land_Area', 'Coastline_Coverage', 'Border_Coverage',
#        'Waterway_Coverage'],
#       dtype='object')

# %%
# Handle Null Values (NaN)

exclude_column = "Capital_Cities_By_Total_Population"

numeric_cols = df.select_dtypes(include="number").columns

if exclude_column in numeric_cols:
    numeric_cols = numeric_cols.drop(exclude_column)

df[numeric_cols] = df[numeric_cols].fillna(
    df[numeric_cols].median()
)

# %%
# Convert Strings to Numbers (string → numeric)
for col in df.columns[2:]:
    df[col] = pd.to_numeric(df[col], errors="coerce")
# df.columns

# %%
# Label Encoding (Text → Number)
df["Country_Encoded"] = df["Country"].astype("category").cat.codes

# %%
# Replace missing Navy Force tonnage values with 0
# Reason: Countries without naval tonnage data either do not operate
df["Navy_Force_By_Tonnage"] = df["Navy_Force_By_Tonnage"].fillna(0)

# %%
print(df.columns.tolist())
# Out:
# ['Country', 'Rank', 'Total_Population_By_Country', 'Available_Military_Manpower', 'Manpower_Fit_For_Military_Service', 'Manpower_Reaching_Military_Age_Annually', 'Active_Military_Manpower', 'Active_Reserve_Military_Manpower', 'Manpower_Paramilitary', 'Capital_Cities_By_Total_Population', 'Aircraft_Total', 'Aircraft_Total_Fighters', 'Aircraft_Total_Attack_Types', 'Aircraft_Total_Transports', 'Aircraft_Total_Trainers', 'Aircraft_Total_Special_Mission', 'Aircraft_Total_Tanker_Fleet', 'Aircraft_Helicopters_Total', 'Aircraft_Helicopters_Attack', 'Armor_Tanks_Total', 'Armor_Apc_Total', 'Armor_Self_Propelled_Guns_Total', 'Armor_Towed_Artillery_Total', 'Armor_Mlrs_Total', 'Navy_Ships', 'Navy_Force_By_Tonnage', 'Navy_Aircraft_Carriers', 'Navy_Helo_Carriers', 'Navy_Submarines', 'Navy_Destroyers', 'Navy_Frigates', 'Navy_Corvettes', 'Navy_Patrol_Coastal_Craft', 'Navy_Mine_Warfare_Craft', 'Defense_Spending_Budget', 'External_Debt_By_Country', 'Purchasing_Power_Parity', 'Reserves_Of_Foreign_Exchange_And_Gold', 'Major_Serviceable_Airports_By_Country', 'Labor_Force_By_Country', 'Major_Ports_And_Terminals', 'Railway_Coverage', 'Roadway_Coverage', 'Oil_Production_By_Country', 'Oil_Consumption_By_Country', 'Proven_Oil_Reserves_By_Country', 'Natural_Gas_Production_By_Country', 'Natural_Gas_Consumption_By_Country', 'Proven_Natural_Gas_Reserves_By_Country', 'Coal_Production_By_Country', 'Coal_Consumption_By_Country', 'Proven_Coal_Reserves_By_Country', 'Square_Land_Area', 'Coastline_Coverage', 'Border_Coverage', 'Waterway_Coverage', 'Country_Encoded']

# %%
# Final Check
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 57 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  145 non-null    object
#  1   Rank                                     145 non-null    int64
#  2   Total_Population_By_Country              145 non-null    int64
#  3   Available_Military_Manpower              145 non-null    int64
#  4   Manpower_Fit_For_Military_Service        145 non-null    int64
#  5   Manpower_Reaching_Military_Age_Annually  145 non-null    int64
#  6   Active_Military_Manpower                 145 non-null    int64
#  7   Active_Reserve_Military_Manpower         145 non-null    int64
#  8   Manpower_Paramilitary                    145 non-null    int64
#  9   Capital_Cities_By_Total_Population       3 non-null      float64
#  10  Aircraft_Total                           145 non-null    int64
#  11  Aircraft_Total_Fighters                  145 non-null    int64
#  12  Aircraft_Total_Attack_Types              145 non-null    int64
#  13  Aircraft_Total_Transports                145 non-null    int64
#  14  Aircraft_Total_Trainers                  145 non-null    int64
#  15  Aircraft_Total_Special_Mission           145 non-null    int64
#  16  Aircraft_Total_Tanker_Fleet              145 non-null    int64
#  17  Aircraft_Helicopters_Total               145 non-null    int64
#  18  Aircraft_Helicopters_Attack              145 non-null    int64
#  19  Armor_Tanks_Total                        145 non-null    int64
#  20  Armor_Apc_Total                          145 non-null    int64
#  21  Armor_Self_Propelled_Guns_Total          145 non-null    int64
#  22  Armor_Towed_Artillery_Total              145 non-null    int64
#  23  Armor_Mlrs_Total                         145 non-null    int64
#  24  Navy_Ships                               145 non-null    int64
#  25  Navy_Force_By_Tonnage                    145 non-null    float64
#  26  Navy_Aircraft_Carriers                   145 non-null    int64
#  27  Navy_Helo_Carriers                       145 non-null    int64
#  28  Navy_Submarines                          145 non-null    int64
#  29  Navy_Destroyers                          145 non-null    int64
#  30  Navy_Frigates                            145 non-null    int64
#  31  Navy_Corvettes                           145 non-null    int64
#  32  Navy_Patrol_Coastal_Craft                145 non-null    int64
#  33  Navy_Mine_Warfare_Craft                  145 non-null    int64
#  34  Defense_Spending_Budget                  145 non-null    int64
#  35  External_Debt_By_Country                 145 non-null    int64
#  36  Purchasing_Power_Parity                  145 non-null    int64
#  37  Reserves_Of_Foreign_Exchange_And_Gold    145 non-null    int64
#  38  Major_Serviceable_Airports_By_Country    145 non-null    int64
#  39  Labor_Force_By_Country                   145 non-null    int64
#  40  Major_Ports_And_Terminals                145 non-null    int64
#  41  Railway_Coverage                         145 non-null    int64
#  42  Roadway_Coverage                         145 non-null    int64
#  43  Oil_Production_By_Country                145 non-null    int64
#  44  Oil_Consumption_By_Country               145 non-null    int64
#  45  Proven_Oil_Reserves_By_Country           145 non-null    int64
#  46  Natural_Gas_Production_By_Country        145 non-null    int64
#  47  Natural_Gas_Consumption_By_Country       145 non-null    int64
#  48  Proven_Natural_Gas_Reserves_By_Country   145 non-null    int64
#  49  Coal_Production_By_Country               145 non-null    int64
#  50  Coal_Consumption_By_Country              145 non-null    int64
#  51  Proven_Coal_Reserves_By_Country          145 non-null    int64
#  52  Square_Land_Area                         145 non-null    int64
#  53  Coastline_Coverage                       145 non-null    int64
#  54  Border_Coverage                          145 non-null    int64
#  55  Waterway_Coverage                        145 non-null    int64
#  56  Country_Encoded                          145 non-null    int16
# dtypes: float64(2), int16(1), int64(53), object(1)
# memory usage: 63.8+ KB
#          Country  Rank  Total_Population_By_Country  \
# 0  United States     1                    341963408
# 1         Russia     2                    140820810
# 2          China     3                   1415043270
# 3          India     4                   1409128296
# 4    South Korea     5                     52081799
#
#    Available_Military_Manpower  Manpower_Fit_For_Military_Service  \
# 0                    150463900                          124816644
# 1                     69002197                           46189226
# 2                    764123366                          626864169
# 3                    662290299                          522786598
# 4                     26040900                           21353538
#
#    Manpower_Reaching_Military_Age_Annually  Active_Military_Manpower  \
# 0                                  4445524                   1328000
# 1                                  1267387                   1320000
# 2                                 19810606                   2035000
# 3                                 23955181                   1455550
# 4                                   416654                    600000
#
#    Active_Reserve_Military_Manpower  Manpower_Paramilitary  \
# 0                            799500                      0
# 1                           2000000                 250000
# 2                            510000                 625000
# 3                           1155000                2527000
# 4                           3100000                 120000
#
#    Capital_Cities_By_Total_Population  ...  \
# 0                                 NaN  ...
# 1                                 NaN  ...
# 2                                 NaN  ...
# 3                                 NaN  ...
# 4                                 NaN  ...
#
#    Natural_Gas_Consumption_By_Country  Proven_Natural_Gas_Reserves_By_Country  \
# 0                        914301000000                          13402000000000
# 1                        472239000000                          47805000000000
# 2                        366160000000                           6654000000000
# 3                         58867000000                           1381000000000
# 4                         59480000000                              7079000000
#
#    Coal_Production_By_Country  Coal_Consumption_By_Country  \
# 0                   548849000                    476044000
# 1                   508190000                    310958000
# 2                  4827000000                   5313000000
# 3                   985671000                   1200000000
# 4                    15595000                    136413000
#
#    Proven_Coal_Reserves_By_Country  Square_Land_Area  Coastline_Coverage  \
# 0                     248941000000           9833517               19924
# 1                     162166000000          17098242               37653
# 2                     143197000000           9596960               14500
# 3                     111052000000           3287263                7000
# 4                        326000000             99720                2413
#
#    Border_Coverage  Waterway_Coverage  Country_Encoded
# 0            12002              41009              137
# 1            22407             102000              107
# 2            22457              27700               28
# 3            13888              14500               53
# 4              237               1600              117
#
# [5 rows x 57 columns]

# %%
# Save final clean dataset
df.to_csv("Global_Military_Data_Cleaned.csv", index=False)

print("✅ Final cleaned dataset saved successfully")
# Out:
# ✅ Final cleaned dataset saved successfully
